# %% [markdown]
# # Session 1 - Introduction to Python

# %% [markdown]
# # Python

# %% [markdown]
# Python is a general-purpose interpreted, interactive, object-oriented, and high-level programming language. It was created by Guido van Rossum during 1985- 1990.
#
# Language is not named after a snake, but after a comedy show "Flying Circus" which Monty Python was a fan of.
#
# Why to Learn Python? Python is a high-level, interpreted, interactive and object-oriented scripting language. Python is designed to be highly readable. It uses English keywords frequently where as other languages use punctuation, and it has fewer syntactical constructions than other languages.

# %% [markdown]
# # Applications of Python

# %% [markdown]
# * Easy-to-learn − Python has few keywords, simple structure, and a clearly defined syntax. This allows the student to pick up the language quickly.
#
# * Easy-to-read − Python code is more clearly defined and visible to the eyes.
#
# * Easy-to-maintain − Python's source code is fairly easy-to-maintain.
#
# * A broad standard library − Python's bulk of the library is very portable and cross-platform compatible on UNIX, Windows, and Macintosh.
#
# * Interactive Mode − Python has support for an interactive mode which allows interactive testing and debugging of snippets of code.
#
# * Portable − Python can run on a wide variety of hardware platforms and has the same interface on all platforms.
#
# * Extendable − You can add low-level modules to the Python interpreter. These modules enable programmers to add to or customize their tools to be more efficient.
#
# * Databases − Python provides interfaces to all major commercial databases.
#
# * GUI Programming − Python supports GUI applications that can be created and ported to many system calls, libraries and windows systems, such as Windows MFC, Macintosh, and the X Window system of Unix.
#
# * Scalable − Python provides a better structure and support for large programs than shell scripting.

# %% [markdown]
# # Python Keywords

# %% [markdown]
# Python Keywords are special reserved words which convey a special meaning to the compiler/interpreter. Each keyword have a special meaning and a specific operation. These keywords can't be used as variable.
#
# Following is the List of Python Keywords:
#
# ‘False’, ‘None’, ‘True’, ‘and’, ‘as’, ‘assert’, ‘async’, ‘await’, ‘break’, ‘class’, ‘continue’, ‘def’, ‘del’, ‘elif’, ‘else’, ‘except’, ‘finally’, ‘for’, ‘from’, ‘global’, ‘if’, ‘import’, ‘in’, ‘is’, ‘lambda’, ‘nonlocal’, ‘not’, ‘or’, ‘pass’, ‘raise’, ‘return’, ‘try’, ‘while’, ‘with’, ‘yield’.

# %% [markdown]
# # VARIABLES

# %% [markdown]
# Python Variable is containers which store values. Python is not “statically typed”. We do not need to declare variables before using them or declare their type. A variable is created the moment we first assign a value to it. A Python variable is a name given to a memory location. It is the basic unit of storage in a program.
#
# Rules for creating variables in Python
#
# * A variable name must start with a letter or the underscore character.
# * A variable name cannot start with a number.
# * A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ ).
# * Variable names are case-sensitive (name, Name and NAME are three different variables).
# * The reserved words(keywords) cannot be used naming the variable.

# %%
# type your code here
a = 2
print(a)
print( type(a) )
b = "Hello world!"
print(b)
print( type(b) )
# Out:
# 2
# <class 'int'>
# Hello world!
# <class 'str'>
# 23.15
# <class 'float'>

# %%
c = 23.15
#execute the value of c and type of c in the below cell

# %%
#answer here

# %%
a=1
b1=2
c=a+b1
print(c)
# Out:
# 3

# %%
c1=2
c3=5
d=c1+c3
#find the value of d in the below cell

# %%
#answer here

# %%
a0=10
b1=30
c_2=a0+b1
print("c_2=",c_2)
print("Addition of a0=",a0," and b1=",b1," is c_2=",c_2)
# Out:
# c_2= 40
# Addition of a0= 10  and b1= 30  is c_2= 40

# %% [markdown]
# # IDENTATION

# %% [markdown]
# In simple terms indentation refers to adding white space before a statement. It is a way of telling a Python interpreter that the group of statements belongs to a particular block of code

# %%
if 5 > 2:
    print("Five is greater than two!")
# Out:
# Five is greater than two!

# %%
if 5<2:
print('Five is less than 2')
#find the ouput in this case in below cell
# Out:
#   Input In [17]
#     print('Five is less than 2')
#     ^
# IndentationError: expected an indented block

# %%
#answer here

# %% [markdown]
# # SINGLE AND DOUBLE QUOTES IN PYTHON

# %% [markdown]
# Generally, double quotes are used for string representation and single quotes are used for regular expressions, dict keys or SQL Hence both single quote and double quotes depict string in python but it’s sometimes our need to use one type over the other.

# %%
# this code prints the output within quotes.
# print WithQuotes within single quotes
print("'WithQuotes'")
# Out:
# 'WithQuotes'

# %%
print("Hello 'Python'")
#find the ouput in this case

# %%
#answer here

# %% [markdown]
# # Python print() Function

# %%
print("My name is Ayush")
print("c")
print(c)
# Out:
# My name is Ayush
# c
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 3>()
#       1 print("My name is Ayush")
#       2 print("c")
# ----> 3 print(c)
#
# NameError: name 'c' is not defined

# %%
print('My name is Jay')
#what should be ouput in this case in below cell

# %%
#answer here

# %% [markdown]
# # Escape sequences

# %% [markdown]
# You can represent any member of the execution character set by an escape sequence. They are primarily used to put nonprintable characters in character and string literals. For example, you can use escape sequences to put such characters as tab, carriage return, and backspace into an output stream.

# %%
print('This is Batman's car')
# Out:
#   Input In [4]
#     print('This is Batman's car')
#                           ^
# SyntaxError: invalid syntax

# %%
print('This is Batman\'s car')
# \ is called escape Character
#find the output in below cell

# %%
#answer here

# %% [markdown]
# # New line Escape Charecter

# %% [markdown]
# Suppose I give a string, so it will not be considered a new line. What if we want to print some part of the particular string in the new line?
#
# We can use “\n” here, which tells the interpreter to print some characters in the new line separately.

# %%
print('Twinkel Twinkle \nLittle Star')
# Out:
# Twinkel Twinkle
# Little Star

# %% [markdown]
# # Horizontal tab Escape Charecter

# %% [markdown]
# If we want to add tab space between words, then this escape sequence will give the tab space between the words or characters using “\t”.

# %%
print('lemo\tzin')
# Out:
# lemo	zin

# %%
print('acio\tjobs')
#find the output in below cell

# %%
#answer here

# %% [markdown]
# # PARAMETERS

# %% [markdown]
# A parameter is the variable listed inside the parentheses in the function definition. An argument is the value that is sent to the function when it is called.
#
# SEP()
#
# The separator between the arguments to print() function in Python is space by default (softspace feature) , which can be modified and can be made to any character, integer or string as per our choice
#
# END()
#
# The end parameter in the print function is used to add any string.By default, the print function ends with a newline. Passing the whitespace to the end parameter (end=' ') indicates that the end character has to be identified by whitespace and not a newline

# %%
#code for disabling the softspace feature


print('ubaid','gmail.com',sep="@")
# Out:
# ubaid@gmail.com

# %%
print('09','12','2016')
print('09','12','2016', sep='/')
print('09','12','2016', sep='-')

#find the output in below cell

# %%
#answer here

# %% [markdown]
# # Standard data types

# %% [markdown]
# Number stores numeric values. The integer, float, and complex values belong to a Python Numbers data-type.
#
# Python supports three types of numeric data.
#
# int - Integer value can be any length such as integers 10, 2, 29, -20, -150 etc. Python has no restriction on the length of an integer. Its value belongs to int.
#
# float - Float is used to store floating-point numbers like 1.9, 9.902, 15.2, etc. It is accurate upto 15 decimal points.
#
# complex - We can write a complex number c=a+ib with real part Re(c)=a, imaginary part Im(c)=b, and imaginary unit i=√-1. In Python, the symbol j is used to denote the imaginary unit. Furthermore, a coefficient before j is needed. To specify a complex number, one can also use the constructor complex. The complex numbers like 2.14j, 2.0 + 2.3j, etc.

# %%
x=5
print(type(x))
# Out:
# <class 'int'>

# %%
x=20-6j
y=20+6j
z=6j
a=20+0j
b=-20+1j


print(x,type(x))
print(y,type(y))
print(z,type(z))
print(a,type(a))
print(b,type(b))
# Out:
# (20-6j) <class 'complex'>
# (20+6j) <class 'complex'>
# 6j <class 'complex'>
# (20+0j) <class 'complex'>
# (-20+1j) <class 'complex'>

# %%
x=True
y=False
print(x,type(x))
print(y,type(y))
# Out:
# True <class 'bool'>
# False <class 'bool'>

# %% [markdown]
# # String

# %% [markdown]
# A string is a sequence of characters.Strings in python are surrounded by either single quotation marks, or double quotation marks. For Multiline strings It is surrounded by triple either single quotation marks, or double quotation marks.

# %%
s=[1,2,3,4]

# %%
x='My name is James Bond and this is Batman\'s car'
print(x)
# Out:
# My name is James Bond and this is Batman's car

# %%
t='My name is abc'
#execute this in below cell

# %%
#answer here

# %% [markdown]
# f-string

# %% [markdown]
# PEP 498 introduced a new string formatting mechanism known as Literal String Interpolation or more commonly as F-strings (because of the leading f character preceding the string literal). The idea behind f-strings is to make string interpolation simpler. To create an f-string, prefix the string with the letter “ f ”. The string itself can be formatted in much the same way that you would with str.format(). F-strings provide a concise and convenient way to embed python expressions inside string literals for formatting.

# %%
x=20
y='Sahil'

print(f'My name is {y} and my age is {x}')
# Out:
# My name is Sahil and my age is 20

# %%
z= 20
v= 'Kartik'

#using f string method find the output using sentence form in below cell

# %%
#answer here

# %% [markdown]
# Formatting string using % Operator

# %% [markdown]
# It is the oldest method of string formatting. Here we use the modulo % operator. The modulo % is also known as the “string-formatting operator”.

# %%
name=input('Name: ')
age=int(input('Age: '))
gender=input('Gender: ')
mobile=int(input("Mobile: "))

print('My name is %s. I am %d old %s. My mobile number is %d'%(name,age,gender,mobile))
# Out:
# Name: Ankit
# Age: 23
# Gender: M
# Mobile: 94504544554
# My name is Ankit. I am 23 old M. My mobile number is 94504544554

# %% [markdown]
# Formatting string using format() method

# %% [markdown]
# Format() method was introduced with Python3 for handling complex string formatting more efficiently. Formatters work by putting in one or more replacement fields and placeholders defined by a pair of curly braces { } into a string and calling the str.format(). The value we wish to put into the placeholders and concatenate with the string passed as parameters into the format function.

# %%
x=10
y=3
z=x/y

print('When we divide {} by {} we get {}'.format(x,y,z))
# Out:
# When we divide 10 by 3 we get 3.3333333333333335

# %% [markdown]
# String slicing

# %% [markdown]
# String slicing is about obtaining a sub-string from the given string by slicing it respectively from start to end or end to start according to index posiotion of the charecters of the string.
#
# Python is a Zero index language i.e. First element of the sequence is at 0 index.
#
# In python we can also apply negative index i.e. last element of the sequence is at -1 index.
#
# Specify the start index and the end index, separated by a colon, to return a part of the string.Also the end part of the array is a step to skip the elements in the sequence. All are will be included inside a '[ ]' bracket.

# %%
# slice the string from 2nd elements to 3rd element
a='Mango'
a[1:3]
# Out:
# 'an'

# %%
a[2]
# Out:
# 'n'

# %%
a[-1]
# Out:
# 'o'

# %%
#Find the value at 3rd index in below cell

# %%
#answer here

# %% [markdown]
# String Methods

# %% [markdown]
# Strings in Python have many built-in methods that are used to manipulate them.
#
# Methods: Methods are functions associated with data types and are accessed using the . notation

# %%
# upper(): Converts all lowercase characters in a string into uppercase
x='mango'

print(x.upper())
# Out:
# MANGO

# %%
# lower(): Converts all uppercase characters in a string into lowercase
x='MANGO'
print(x.lower())
# Out:
# mango

# %%
# capitalize()	Converts the first character to upper case
x.capitalize()
# Out:
# 'Mango'

# %%
x='mango'

# %%
# isalpha(): Returns “True” if all characters in the string are alphabets
x.isalpha()
# Out:
# True

# %%
# isdigit(): Returns “True” if all characters in the string are digits
x='25698'
x.isdigit()
# Out:
# True

# %%
# isalnum(): Checks whether all the characters in a given string is alphanumeric or not
x='mango1'
x.isalnum()
# Out:
# True

# %% [markdown]
# # Operators

# %% [markdown]
# Arithmetic:
#
# Comparison:
#
# Logical:
#
# Membership:
#
# Identity:

# %% [markdown]
# # Arithmatica Operators

# %%
print(2+3)   # Addition
print(3-2)   # Subtraction
print(2*3)   # Multiplication
print(6/4)   # Division
print(6//4)  # Floor Division
print(6%4)   # Modulus or Modulo
print(2**3)  # Exponentiation
# Out:
# 5
# 1
# 6
# 1.5
# 1
# 2
# 8

# %% [markdown]
# # Comparison Operators

# %%
print(2<3)  # Less Than
print(2>3)  # Greater Than
print(3<=3) # Less Than Equal To
print(3<=4) # Less Than Equal To
print(3>=2) # Greater Than Equal To
print(3==3) # Equal To
print(4==3) # Equal To
print(4!=3) # Not Equal To
print(3!=3) # Not Equal To
# Out:
# True
# False
# True
# True
# True
# True
# False
# True
# False

# %% [markdown]
# # Logical Operators

# %% [markdown]
# and

# %% [markdown]
# The 'and' operator evaluates True If the expression or value of both of the operands is True; False otherwise.

# %%
print(3>2 and 5<10)
# Out:
# True

# %%
#(3>2 and 2>5)
#what will be output on executive this command

# %%
#answer here

# %% [markdown]
# or

# %% [markdown]
# The expression is False *only if both the statements around the operator are false. Otherwise, it is *True

# %%
print(3>2 or 2<5)
# Out:
# True

# %%
print(3<2 or 5>2)
# Out:
# True

# %% [markdown]
# not
# This inverts the Boolean value of an expression. It converts True to False, and False to True.
#
# not True ----->> False
#
# not False ----->> True

# %%
s=True
t=False
print(not s)
# Out:
# False

# %%
#find the output of not t in below cell

# %%
#answer here

# %% [markdown]
# # Membership Operators

# %% [markdown]
# These operators test whether a value is a member of a sequence. The sequence may be a list, a string, or a tuple.
#
# We have two membership python operators- ‘in’ and ‘not in’.

# %%
s = "Dashing Dude"
print('D in s --->>',"D" in s)
print('s in s -->>',"s" in s)
print('d in s -->>',"d" in s)
print('D not in s -->>',"D" not in s)
print('d not in s -->>',"d" not in s)
print("Dude in s -->>",'Dude' in s)
print("Da not in s -->>",'Da' not in s)
# Out:
# D in s --->> True
# s in s -->> True
# d in s -->> True
# D not in s -->> False
# d not in s -->> False
# Dude in s -->> True
# Da not in s -->> False

# %% [markdown]
# # Identity Operator

# %% [markdown]
# These operators test if the two operands share an identity. We have two identity operators- ‘is’ and ‘is not’.

# %%
a = 2
b = 2
print('a=',id(a))
print('b=',id(b))
print('a is b -->>',a is b)
b = 25
print('old a=',id(a))
print('new b=',id(b))
print('a is b -->>',a is b)
# Out:
# a= 2577237502288
# b= 2577237502288
# a is b -->> True
# old a= 2577237502288
# new b= 2577237503024
# a is b -->> False
