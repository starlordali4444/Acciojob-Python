# %% [markdown]
#     Doubts
#         loc
#         iloc
#     Dataframe => Explain again
#     iterable
#     Itertools
#     Pandas Practice Questions
#
#     File Handling
#
#     Portal Questions
#     () => moon bracket => whenever we have function we use this
#     [] => square bracket => for slicing we use this

# %%
import numpy as np
import pandas as pd

# %%
df_bigmart=pd.read_csv('../data/bigmart_data_10.csv',index_col='idx')
df_bigmart.head()
# Out:
#     Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# idx
# a             FDA15         9.30          Low Fat         0.016047
# b             DRC01         5.92          Regular         0.019278
# c             FDN15        17.50          Low Fat         0.016760
# d             FDX07        19.20          Regular         0.000000
# e             NCD19         8.93          Low Fat         0.000000
#
#                  Item_Type  Item_MRP Outlet_Identifier  \
# idx
# a                    Dairy  249.8092            OUT049
# b              Soft Drinks   48.2692            OUT018
# c                     Meat  141.6180            OUT049
# d    Fruits and Vegetables  182.0950            OUT010
# e                Household   53.8614            OUT013
#
#      Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# idx
# a                         1999      Medium               Tier 1
# b                         2009      Medium               Tier 3
# ...

# %% [markdown]
#     df.loc[start_row_label:end_row_label:step,start_col_label,end_col_label,step]

# %%
df_bigmart.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
df_bigmart.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k'], dtype='object', name='idx')

# %%
df_bigmart.shape
# Out:
# (8523, 12)

# %%
df_bigmart.loc[['a', 'b', 'c', 'd', 'e'],['Item_Identifier', 'Item_Weight', 'Item_Fat_Content','Item_MRP']]
# Out:
#     Item_Identifier  Item_Weight Item_Fat_Content  Item_MRP
# idx
# a             FDA15         9.30          Low Fat  249.8092
# b             DRC01         5.92          Regular   48.2692
# c             FDN15        17.50          Low Fat  141.6180
# d             FDX07        19.20          Regular  182.0950
# e             NCD19         8.93          Low Fat   53.8614

# %%
cols=list(df_bigmart.columns)
cols
# Out:
# ['Item_Identifier',
#  'Item_Weight',
#  'Item_Fat_Content',
#  'Item_Visibility',
#  'Item_Type',
#  'Item_MRP',
#  'Outlet_Identifier',
#  'Outlet_Establishment_Year',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type',
#  'Item_Outlet_Sales']

# %%
for i in range(len(cols)):
    print(f' index =>{i}  | value =>{cols[i]}')
# Out:
#  index =>0  | value =>Item_Identifier
#  index =>1  | value =>Item_Weight
#  index =>2  | value =>Item_Fat_Content
#  index =>3  | value =>Item_Visibility
#  index =>4  | value =>Item_Type
#  index =>5  | value =>Item_MRP
#  index =>6  | value =>Outlet_Identifier
#  index =>7  | value =>Outlet_Establishment_Year
#  index =>8  | value =>Outlet_Size
#  index =>9  | value =>Outlet_Location_Type
#  index =>10  | value =>Outlet_Type
#  index =>11  | value =>Item_Outlet_Sales

# %%
df_bigmart.iloc[::2,0:11:2]
# Out:
#     Item_Identifier Item_Fat_Content              Item_Type Outlet_Identifier  \
# idx
# a             FDA15          Low Fat                  Dairy            OUT049
# c             FDN15          Low Fat                   Meat            OUT049
# e             NCD19          Low Fat              Household            OUT013
# g             FDO10          Regular            Snack Foods            OUT013
# i             FDH17          Regular           Frozen Foods            OUT045
# k             FDY07          Low Fat  Fruits and Vegetables            OUT049
#
#     Outlet_Size        Outlet_Type
# idx
# a        Medium  Supermarket Type1
# c        Medium  Supermarket Type1
# e          High  Supermarket Type1
# g          High  Supermarket Type1
# i           NaN  Supermarket Type1
# k        Medium  Supermarket Type1

# %%
rows=list(df_bigmart.index)
rows
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k']

# %%
for i in range(len(rows)):
    print(f' index =>{i}  | value =>{rows[i]}')
# Out:
#  index =>0  | value =>a
#  index =>1  | value =>b
#  index =>2  | value =>c
#  index =>3  | value =>d
#  index =>4  | value =>e
#  index =>5  | value =>f
#  index =>6  | value =>g
#  index =>7  | value =>h
#  index =>8  | value =>i
#  index =>9  | value =>j
#  index =>10  | value =>k

# %%
df_bigmart.iloc[:,:]
# Out:
#     Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# idx
# a             FDA15        9.300          Low Fat         0.016047
# b             DRC01        5.920          Regular         0.019278
# c             FDN15       17.500          Low Fat         0.016760
# d             FDX07       19.200          Regular         0.000000
# e             NCD19        8.930          Low Fat         0.000000
# f             FDP36       10.395          Regular         0.000000
# g             FDO10       13.650          Regular         0.012741
# h             FDP10          NaN          Low Fat         0.127470
# i             FDH17       16.200          Regular         0.016687
# j             FDU28       19.200          Regular         0.094450
# k             FDY07       11.800          Low Fat         0.000000
#
#                  Item_Type  Item_MRP Outlet_Identifier  \
# idx
# a                    Dairy  249.8092            OUT049
# ...

# %% [markdown]
#     Class is a collection of attribute/features and methods
#         Methods => functions
#         Attribute/feature/property =>

# %% [markdown]
#         Class  =>   Dog
#             Attriubute / Properties / Features
#                 Color
#                 Breed
#             Methods / Functions
#                 Bark
#                 running

# %%
df_bigmart.shape

# %%
pd.DataFrame()

# %% [markdown]
#     Iterable
#         initialization
#         condition
#         iteration

# %%
for i in 1:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 for i in 1:
#       2     print(i)
#
# TypeError: 'int' object is not iterable

# %%
for i in 'siraj':
    print(i)
# Out:
# s
# i
# r
# a
# j

# %%
for i in 11.5:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 for i in 11.5:
#       2     print(i)
#
# TypeError: 'float' object is not iterable

# %%
for i in True:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 for i in True:
#       2     print(i)
#
# TypeError: 'bool' object is not iterable

# %% [markdown]
#     Functions
#         Builtin => it is there by default
#         User Define

# %%
! pip install numpy

# %%
import numpy as np

# %%
df_bigmart=pd.read_csv('../data/bigmart_data.csv')
df_bigmart.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
#     Write a python script to get average price for each item type

# %%
df_bigmart.groupby('Item_Type').count()
# Out:
#                        Item_Identifier  Item_Weight  Item_Fat_Content  \
# Item_Type
# Baking Goods                       648          536               648
# Breads                             251          204               251
# Breakfast                          110           89               110
# Canned                             649          539               649
# Dairy                              682          566               682
# Frozen Foods                       856          718               856
# Fruits and Vegetables             1232         1019              1232
# Hard Drinks                        214          183               214
# Health and Hygiene                 520          430               520
# Household                          910          759               910
# Meat                               425          337               425
# Others                             169          137               169
# ...

# %%
df_bigmart.groupby('Item_Type')[['Item_MRP','Item_Weight']].mean()
# Out:
#                          Item_MRP  Item_Weight
# Item_Type
# Baking Goods           126.380766    12.277108
# Breads                 140.952669    11.346936
# Breakfast              141.788151    12.768202
# Canned                 139.763832    12.305705
# Dairy                  148.499208    13.426069
# Frozen Foods           138.503366    12.867061
# Fruits and Vegetables  144.581235    13.224769
# Hard Drinks            137.077928    11.400328
# Health and Hygiene     130.818921    13.142314
# Household              149.424753    13.384736
# Meat                   139.882032    12.817344
# Others                 132.851430    13.853285
# Seafood                141.841719    12.552843
# Snack Foods            146.194934    12.987880
# Soft Drinks            131.492506    11.847460
# Starchy Foods          147.838023    13.690731

# %%
df_bigmart[['Item_Fat_Content','Item_MRP']]
# Out:
#      Item_Fat_Content  Item_MRP
# 0             Low Fat  249.8092
# 1             Regular   48.2692
# 2             Low Fat  141.6180
# 3             Regular  182.0950
# 4             Low Fat   53.8614
# ...               ...       ...
# 8518          Low Fat  214.5218
# 8519          Regular  108.1570
# 8520          Low Fat   85.1224
# 8521          Regular  103.1332
# 8522          Low Fat   75.4670
#
# [8523 rows x 2 columns]

# %%
df_bigmart.groupby('Item_Type')[['Item_MRP','Item_Weight']].agg({'Item_MRP':'max','Item_Weight':'mean'})
# Out:
#                        Item_MRP  Item_Weight
# Item_Type
# Baking Goods           265.5568    12.277108
# Breads                 263.6594    11.346936
# Breakfast              234.9300    12.768202
# Canned                 266.8884    12.305705
# Dairy                  266.6884    13.426069
# Frozen Foods           264.8910    12.867061
# Fruits and Vegetables  264.2252    13.224769
# Hard Drinks            261.4278    11.400328
# Health and Hygiene     266.6884    13.142314
# Household              264.7910    13.384736
# Meat                   261.5936    12.817344
# Others                 254.9040    13.853285
# Seafood                240.2880    12.552843
# Snack Foods            264.9568    12.987880
# Soft Drinks            263.5910    11.847460
# Starchy Foods          263.0252    13.690731

# %% [markdown]
#     File Handling
#         Open
#         Read / write
#         Close

# %%
file=open('../data/test.txt','r')

# %%
file.read()
# Out:
# 'My name is Siraj Ali.\nI am from Lucknow.'

# %%
file=open('../data/test.txt','r')
file.readline()
# Out:
# 'India'

# %%
file=open('../data/test.txt','r')
file.readlines()
# Out:
# ['India\n', 'AcciojobMy name is Shiraj']

# %%
file=open('../data/test.txt','w')
file.write('India')
file.close()

# %%
file=open('../data/test.txt','a')
file.write('My name is Shiraj')
file.close()

# %% [markdown]
#     With => File Context Manager

# %%
with open('../data/test.txt','r') as file:
    content = file.read()
    print(content)
# Out:
# India
# AcciojobMy name is Shiraj

# %%
import os

# %%
dir(os)
# Out:
# ['DirEntry',
#  'EX_OK',
#  'F_OK',
#  'GenericAlias',
#  'Mapping',
#  'MutableMapping',
#  'O_APPEND',
#  'O_BINARY',
#  'O_CREAT',
#  'O_EXCL',
#  'O_NOINHERIT',
#  'O_RANDOM',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SEQUENTIAL',
#  'O_SHORT_LIVED',
#  'O_TEMPORARY',
#  'O_TEXT',
#  'O_TRUNC',
#  'O_WRONLY',
#  'P_DETACH',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_OVERLAY',
#  'P_WAIT',
#  'PathLike',
#  'R_OK',
#  'SEEK_CUR',
#  'SEEK_END',
#  'SEEK_SET',
#  'TMP_MAX',
#  'W_OK',
#  'X_OK',
#  '_AddedDllDirectory',
#  '_Environ',
#  '__all__',
#  '__builtins__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_check_methods',
#  '_execvpe',
#  '_exists',
#  '_exit',
#  '_fspath',
#  '_get_exports_list',
#  '_wrap_close',
#  'abc',
#  'abort',
#  'access',
#  'add_dll_directory',
#  'altsep',
#  'chdir',
#  'chmod',
#  'close',
#  'closerange',
#  'cpu_count',
#  'curdir',
#  'defpath',
#  'device_encoding',
#  'devnull',
#  'dup',
# ...

# %%
os.getcwd()
# Out:
# 'a:\\work\\acciojob\\python\\da3\\code'

# %%
os.listdir('../data/csv/')
# Out:
# ['bank-additional.csv',
#  'bg.csv',
#  'bigmart_data.csv',
#  'bigmart_data_10.csv',
#  'student_records.csv',
#  'super_store.xlsx',
#  'tik_tok.csv']

# %%
dfs={}
for file in os.listdir('../data/csv/'):
    if file[-3:]=='csv':
        dfs[file[:-4]]=pd.read_csv(f'../data/csv/{file}')

# %%
dfs.keys()
# Out:
# dict_keys(['bank-additional', 'bg', 'bigmart_data', 'bigmart_data_10', 'student_records', 'tik_tok'])

# %%
dfs['student_records']
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y             90            85       Yes
# 1    John            C        N             85            51       Yes
# 2   David            F        N             10            17        No
# 3  Holmes            B        Y             75            71        No
# 4  Marvin            E        N             20            30        No
# 5   Simon            A        Y             92            79       Yes
# 6  Robert            B        Y             60            59        No
# 7   Trent            C        Y             75            65        No
# 8    Judy          NaN        Y             25            33        No
# 9   Chris            D        U             25            15        NO

# %%
df_bigmart=pd.read_csv('../data/csv/bigmart_data.csv')
df_bigmart.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df_bigmart['Item_Weight'].isnull().sum()
# Out:
# 1463

# %%
df_bigmart['Item_Weight'].value_counts(dropna=False,normalize=True)[np.nan]*100
# Out:
# 17.165317376510618

# %%
df_bigmart['Outlet_Size'].value_counts(dropna=False)
# Out:
# Outlet_Size
# Medium    2793
# NaN       2410
# Small     2388
# High       932
# Name: count, dtype: int64

# %% [markdown]
#     If we are getting High and medium => acceptable
#     if we are geeting nan Small =>  Non Acceptable
#     np.where(logical_test, value_if_true,value_if_false)
#     np.where(logical_test, value_if_true,np.where())

# %%
df_bigmart['Is_Acceptable']=np.where(df_bigmart['Outlet_Size'] == 'High' ,'Acceptable',np.where(df_bigmart['Outlet_Size'] == 'Medium' ,'Acceptable','Not Acceptable'))
df_bigmart[['Is_Acceptable','Outlet_Size']]
# Out:
#        Is_Acceptable Outlet_Size
# 0         Acceptable      Medium
# 1         Acceptable      Medium
# 2         Acceptable      Medium
# 3     Not Acceptable         NaN
# 4         Acceptable        High
# ...              ...         ...
# 8518      Acceptable        High
# 8519  Not Acceptable         NaN
# 8520  Not Acceptable       Small
# 8521      Acceptable      Medium
# 8522  Not Acceptable       Small
#
# [8523 rows x 2 columns]

# %%
df=df_bigmart

# %%
oldest_outlet = df['Outlet_Establishment_Year'].min()
newest_outlet = df['Outlet_Establishment_Year'].max()
oldest_outlet_performance = df[df['Outlet_Establishment_Year'] == oldest_outlet]['Item_Outlet_Sales'].mean()
newest_outlet_performance = df[df['Outlet_Establishment_Year'] == newest_outlet]['Item_Outlet_Sales'].mean()

# %%
oldest_outlet,newest_outlet,oldest_outlet_performance,newest_outlet_performance
# Out:
# (1985, 2009, 2483.6774743677374, 1995.498739224138)

# %%
import datetime as dt

# %%
today=dt.datetime.now()
today
# Out:
# datetime.datetime(2023, 12, 28, 22, 29, 20, 280260)

# %%
today.month
# Out:
# 12
